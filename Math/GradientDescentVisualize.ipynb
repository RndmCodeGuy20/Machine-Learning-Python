# %% [markdown]
# # Let's Visualize Gradient Descent Method

# %% [markdown]
# Let's assume there is a graph, having `height` on y-axis and `weight` on x-axis. We need to find the equation of the line that perfectly fits the data points.

# %% [markdown]
# <center><svg version="1.1" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 600.8726496388281 415.72987711869064" width="600.8726496388281" height="415.72987711869064">
#   <!-- svg-source:excalidraw -->
#
#   <defs>
#     <style>
#       @font-face {
#         font-family: "Virgil";
#         src: url("https://excalidraw.com/Virgil.woff2");
#       }
#       @font-face {
#         font-family: "Cascadia";
#         src: url("https://excalidraw.com/Cascadia.woff2");
#       }
#     </style>
#   </defs>
#   <rect x="0" y="0" width="600.8726496388281" height="415.72987711869064" fill="#ffffff"></rect><g stroke-linecap="round"><g transform="translate(59.499630287786204 402.41948320239044) rotate(0 195.94470260622393 0)"><path d="M0 0 C87.66 0, 175.32 0, 391.89 0 M0 0 C107.49 0, 214.99 0, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g><g transform="translate(59.499630287786204 402.41948320239044) rotate(0 195.94470260622393 0)"><path d="M363.7 10.26 C370 7.97, 376.31 5.67, 391.89 0 M363.7 10.26 C371.43 7.45, 379.16 4.63, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g><g transform="translate(59.499630287786204 402.41948320239044) rotate(0 195.94470260622393 0)"><path d="M363.7 -10.26 C370 -7.97, 376.31 -5.67, 391.89 0 M363.7 -10.26 C371.43 -7.45, 379.16 -4.63, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g></g><g stroke-linecap="round"><g transform="translate(-137.8925476990571 205.94470260622347) rotate(270 195.94470260622393 0)"><path d="M0 0 C104.13 0, 208.26 0, 391.89 0 M0 0 C147.08 0, 294.16 0, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g><g transform="translate(-137.8925476990571 205.94470260622347) rotate(270 195.94470260622393 0)"><path d="M363.7 10.26 C371.19 7.53, 378.68 4.81, 391.89 0 M363.7 10.26 C374.28 6.41, 384.86 2.56, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g><g transform="translate(-137.8925476990571 205.94470260622347) rotate(270 195.94470260622393 0)"><path d="M363.7 -10.26 C371.19 -7.53, 378.68 -4.81, 391.89 0 M363.7 -10.26 C374.28 -6.41, 384.86 -2.56, 391.89 0" stroke="#000000" stroke-width="4" fill="none"></path></g></g><g stroke-linecap="round" transform="translate(101.31177347703851 302.85141183890664) rotate(0 13.356970650167568 12.571277954255493)"><path d="M11.24 0.6 C13.96 -0.13, 18.08 0.13, 20.52 1.34 C22.96 2.55, 24.99 5.1, 25.88 7.88 C26.77 10.65, 26.8 15.45, 25.85 18 C24.91 20.54, 22.64 22.07, 20.21 23.15 C17.77 24.23, 14.15 25.1, 11.24 24.46 C8.33 23.81, 4.72 21.42, 2.75 19.29 C0.78 17.16, -0.71 14.15, -0.6
#82c91e"></path><path d="M8.53 0.69 C10.88 -0.15, 14.51 0.68, 17.32 1.65 C20.13 2.61, 23.74 4.15, 25.4 6.46 C27.05 8.78, 27.86 13.04, 27.27 15.56 C26.69 18.08, 24.23 20.1, 21.9 21.6 C19.57 23.09, 16.14 24.57, 13.3 24.53 C10.46 24.48, 7.12 23.12, 4.88 21.34 C2.65 19.56, 0.22 16.38, -0.11 13.84 C-0.44 11.3, 0.92 8.51, 2.89 6.11 C4.86 3.72, 9.8 0.32, 11.72 -0.53 C13.64 -1.37, 14.49 0.67, 14.4 1.04 M18.4 -0.2 C21.33 0.46, 24.3 3.38, 25.8 5.77 C27.29 8.15, 27.95 11.32, 27.36 14.12 C26.76 16.92, 24.57 20.62, 22.25 22.57 C19.92 24.53, 16.49 26.15, 13.43 25.87 C10.37 25.59, 6.21 22.65, 3.89 20.91 C1.56 19.16, -0.09 17.76, -0.54 15.38 C-0.98 13, -0.4 9.19, 1.23 6.64 C2.85 4.08, 6.58 0.88, 9.22 0.05 C11.87 -0.78, 15.75 1.39, 17.1 1.67 C18.45 1.94, 17.23 1.81, 17.34 1.68" stroke="#e67700" stroke-width="2" fill="none"></path></g><g stroke-linecap="round"><g transform="translate(10.486561804636949 406.1547487664211) rotate(0 289.9497630147771 -186.9548065276765)"><path d="M-0.49 -0.42 C95.76 -62.36, 481.65 -309.58, 578.19 -371.7 M1.46 -1.69 C98.01 -63.97, 484.34 -311.73, 580.39 -373.48" stroke="#d9480f" stroke-width="2" fill="none"></path></g></g></svg></center>

# %% [markdown]
# > Assumption : slope of the line was found to be 0.2027 (using linear regression)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
colors = ["#ffbe0b", "#fb5607", "#ff006e", "#8338ec", "#3a86ff",]
font = {'family': 'Arial',
        'color':  colors[4],
        'weight': 'normal',
        'size': 16,
        }

# %%
weightVals = [4.53, 0.53, 5.05]
heightVals = [2.19, 2.63, 4.41]

# %%
plt.figure(figsize=(10,7.5))

plt.scatter(weightVals, heightVals, color='#fff', alpha=0.7, edgecolors=colors[2], s=50)

plt.xlabel("Weight", fontdict=font)
plt.ylabel("Height", fontdict=font)

plt.show()

# %%
weight = np.array(weightVals)
height = 0.2027*weight + 2.3935

plt.figure(figsize=(10,7.5))

plt.plot(weight, height, color=colors[0])
plt.scatter( weightVals, heightVals, color='#fff', alpha=0.7, edgecolors=colors[2], s=50)

plt.xlabel("Weight", fontdict=font)
plt.ylabel("Height", fontdict=font)
plt.title("Actual Regression Line")

plt.show()

# %%
height
# Out:
# array([3.311731, 2.500931, 3.417135])

# %%
# Plotting the gradient descent plot
c = 0.0
plt.figure(figsize=(10,7.5))

while c <= 5:
    sumSquared = 0
    for i in range(3):
        predHeight = 0.2027*weightVals[i] + c
        sumSquared += (heightVals[i] - predHeight)**2
    plt.scatter(c, sumSquared, color=colors[1], s=10)
    c += 0.1
